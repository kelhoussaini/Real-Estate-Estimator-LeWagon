# %%
# %reload_ext autoreload 
# %autoreload 2

# %%
# !set PATH=%PATH%; /home/krystelle/code/Krys28/reestimator/

# %%
from reestimator.Mysql_mgmt.get_data import Data_loading

# %% [markdown]
# # TEST FONCTIONS OF GET_DATA CLASS

# %%
getting_data = Data_loading()

# %%
df_test = getting_data.get_num_rows('data_working_update', 3)
df_test
# Out:
#   id_mutation date_mutation nature_mutation  valeur_fonciere adresse_suffixe  \
# 0      2016-1    2016-01-08           Vente            40000
# 1      2016-4    2016-01-08           Vente            90000
# 2      2016-6    2016-01-04           Vente           203700
#
#     adresse_nom_voie adresse_code_voie  code_postal  code_commune  \
# 0  RUE TONY REVILLON              0560         1750          1370
# 1              PELUS              B203         1560          1364
# 2           AU BOURG              B014         1190          1050
#
#                 nom_commune  ...   type_local surface_reelle_bati  \
# 0   Saint-Laurent-sur-Saône  ...  Appartement                  50
# 1  Saint-Jean-sur-Reyssouze  ...       Maison                 150
# 2                   Boissey  ...       Maison                  98
#
#   nombre_pieces_principales code_nature_culture nature_culture  \
# 0                         2
# 1                         6                   S           sols
# ...

# %%
getting_data.get_random_rows('data_working_update', 100)
# Out:
#      id_mutation date_mutation nature_mutation  valeur_fonciere  \
# 0   2016-1181028    2016-04-29           Vente           370740
# 1    2018-682990    2018-11-15           Vente           240000
# 2    2017-330048    2017-05-23           Vente           104420
# 3   2017-1147951    2017-02-24           Vente            62000
# 4    2019-164220    2019-07-03           Vente           370000
# ..           ...           ...             ...              ...
# 95   2019-171473    2019-12-20           Vente           355000
# 96  2017-1309067    2017-05-11           Vente           298400
# 97   2016-131399    2016-07-21           Vente           143000
# 98    2019-12989    2019-05-15           Vente           295000
# 99   2020-964593    2020-12-22           Vente           137277
#
#    adresse_suffixe         adresse_nom_voie adresse_code_voie  code_postal  \
# 0                            AV DES PERDRIX              7177        94210
# ...

# %%
# getting_data.get_all_rows('data_working_update') Cette ligne focntionne mais elle met 5min pour s'exécuter.

# %%
getting_data.show_tables()
# Out:
# Engine(mysql+pymysql://Estimators:***@34.77.88.127:3306/Housing_France)
#                 TABLE_NAME
# 0                     data
# 1             data_working
# 2      data_working_update
# 3  data_working_update_old

# %%
data_test = pd.DataFrame()

# %%
# df_test is the DF that is replace by data_test DF (It is empty for the test)
getting_data.data_to_sql(df_test, data_test, if_exists='replace')
# Out:
# the table Empty DataFrame
# Columns: []
# Index: [] was successfully loaded to DB

# %%
getting_data.load_data_chunk('data_working_update', 100000)
# Out:
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# Got dataframe w/100000 rows
# ...
