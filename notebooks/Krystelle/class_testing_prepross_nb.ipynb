# %%
# %reload_ext autoreload 
# %autoreload 2

# %%
# Import library 
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
from collections import namedtuple

# %%
from reestimator.preprocessing.preprocessing import Preprocessing_data

# %% [markdown]
# # TEST FONCTIONS OF THE EXPLORATION_DATA CLASS

# %%
# Get_data from gz
df_2020 = pd.read_csv('../../../Krys28/Project-Real estate estimator/data/csv/2020.gz', compression='gzip')
df_2020.head(10)
# Out:
# /home/krystelle/.pyenv/versions/lewagon/envs/reestimator/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (8,10,12,14,16,17,18,20,22,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2020-1    2020-01-07                   1           Vente
# 1      2020-2    2020-01-02                   1           Vente
# 2      2020-2    2020-01-02                   1           Vente
# 3      2020-2    2020-01-02                   1           Vente
# 4      2020-2    2020-01-02                   1           Vente
# 5      2020-2    2020-01-02                   1           Vente
# 6      2020-3    2020-01-07                   1           Vente
# 7      2020-4    2020-01-07                   1           Vente
# 8      2020-4    2020-01-07                   1           Vente
# ...

# %%
preprocessor = Preprocessing_data(df_2020)

# %%
df_2020.columns
# Out:
# Index(['id_mutation', 'date_mutation', 'numero_disposition', 'nature_mutation',
#        'valeur_fonciere', 'adresse_numero', 'adresse_suffixe',
#        'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune',
#        'nom_commune', 'code_departement', 'ancien_code_commune',
#        'ancien_nom_commune', 'id_parcelle', 'ancien_id_parcelle',
#        'numero_volume', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero',
#        'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez',
#        'lot4_numero', 'lot4_surface_carrez', 'lot5_numero',
#        'lot5_surface_carrez', 'nombre_lots', 'code_type_local', 'type_local',
#        'surface_reelle_bati', 'nombre_pieces_principales',
#        'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale',
#        'nature_culture_speciale', 'surface_terrain', 'longitude', 'latitude'],
#       dtype='object')

# %%
preprocessor.conv_int(df_2020['numero_disposition'])
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 2459555    1
# 2459556    1
# 2459557    1
# 2459558    1
# 2459559    1
# Name: numero_disposition, Length: 2459560, dtype: int8

# %%
preprocessor.conv_downcast()
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1           Vente
# 1              2020-2    2020-01-02                   1           Vente
# 2              2020-2    2020-01-02                   1           Vente
# 3              2020-2    2020-01-02                   1           Vente
# 4              2020-2    2020-01-02                   1           Vente
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1           Vente
# 2459556  2020-1075291    2020-12-16                   1           Vente
# 2459557  2020-1075291    2020-12-16                   1           Vente
# 2459558  2020-1075291    2020-12-16                   1           Vente
# 2459559  2020-1075292    2020-10-08                   1    Adjudication
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...

# %%
preprocessor.conv_date(df_2020['date_mutation'])
# Out:
# 0         2020-01-07
# 1         2020-01-02
# 2         2020-01-02
# 3         2020-01-02
# 4         2020-01-02
#              ...
# 2459555   2020-12-16
# 2459556   2020-12-16
# 2459557   2020-12-16
# 2459558   2020-12-16
# 2459559   2020-10-08
# Name: date_mutation, Length: 2459560, dtype: datetime64[ns]

# %%
df_2020['valeur_fonciere'].shape
# Out:
# (2459560,)

# %%
preprocessor.drop_rows_of_specific_column('valeur_fonciere').shape
# Out:
# (2427808, 40)

# %%
preprocessor.remplacement_mutation()
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1               1
# 1              2020-2    2020-01-02                   1               1
# 2              2020-2    2020-01-02                   1               1
# 3              2020-2    2020-01-02                   1               1
# 4              2020-2    2020-01-02                   1               1
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1               1
# 2459556  2020-1075291    2020-12-16                   1               1
# 2459557  2020-1075291    2020-12-16                   1               1
# 2459558  2020-1075291    2020-12-16                   1               1
# 2459559  2020-1075292    2020-10-08                   1               0
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...

# %%
preprocessor.cadastral_sector()
# Out:
# 0          000AK
# 1          0000B
# 2          0000B
# 3          0000B
# 4          0000C
#            ...
# 2459555    000AW
# 2459556    000AW
# 2459557    000AW
# 2459558    000AW
# 2459559    000AM
# Name: secteur_cadastral, Length: 2459560, dtype: object

# %%
df_2020
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1               1
# 1              2020-2    2020-01-02                   1               1
# 2              2020-2    2020-01-02                   1               1
# 3              2020-2    2020-01-02                   1               1
# 4              2020-2    2020-01-02                   1               1
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1               1
# 2459556  2020-1075291    2020-12-16                   1               1
# 2459557  2020-1075291    2020-12-16                   1               1
# 2459558  2020-1075291    2020-12-16                   1               1
# 2459559  2020-1075292    2020-10-08                   1               0
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...

# %%
preprocessor.filter_dependency(df_2020, 100000)
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1               1
# 1              2020-2    2020-01-02                   1               1
# 2              2020-2    2020-01-02                   1               1
# 3              2020-2    2020-01-02                   1               1
# 4              2020-2    2020-01-02                   1               1
# ...               ...           ...                 ...             ...
# 2459553  2020-1075291    2020-12-16                   1               1
# 2459554  2020-1075291    2020-12-16                   1               1
# 2459555  2020-1075291    2020-12-16                   1               1
# 2459557  2020-1075291    2020-12-16                   1               1
# 2459559  2020-1075292    2020-10-08                   1               0
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...
